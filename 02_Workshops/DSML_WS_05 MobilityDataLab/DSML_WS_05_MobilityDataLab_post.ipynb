# %% [markdown]
# # `DSML Workshop 05` - Hands on Data Science with real-world geotagged data
#
# During this workshop we dive into an excerpt of Car2Go data from the city of Stuttgart (STR). We will work hands-on with the dataset, which you can find on ILIAS. At the end of this session you should:
#
# - understand the dataset and be able to query, analyze and plot it
# - enrich the dataset with further features
# - do basic geographical plots in folium
# - understand the business case behind Virtual Power Plants and how they interact with the ancillary services markets

# %% [markdown]
# ## `Data Preparation and Exploration`

# %% [markdown]
# ### 1.1 Read in data and perform basic transformations
#
# To keep size manageable we have uploaded a 2-week data snippet of Car2Go movement data from the city of Stuttgart (STR). We use data from November, 2017. In the interest of time we have done a lot of the pre-processing for you. Simply execute the code below to read in the data in the desired format.

# %% [markdown]
# **Note**: I received the feedback that some of you are having problems with creating an environment for this notebook. Originally, you needed this environment for pyrosm, the library required to obtain location data. Given the issues with pyrosm, we decided to provide you with the location information for Stuttgart as a csv file, which you can find on ILIAS. Consequently, you do not need to use pyrosm and this updated version of the notebook should work with the environment that you use for all DSML workshops. Additionally, we will provide you with the location data of your team assignment cities, which has been added to the data folder (see link in team assignment document).

# %%
# import all relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
sns.set()
sns.set_style("white")
sns.set_palette("GnBu_d")

# also import these "new" libraries 
# Note: you may have to download an add them to your environment (using e.g. 'conda install -c conda-forge folium')
import folium
from folium import plugins
from folium.plugins import HeatMap
import geopandas as gpd
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
import math
import random

# %%
STR_Nov = pd.read_csv("Car2Go_STR_Nov.csv", encoding = "ISO-8859-1") # read in data
STR_Nov.sort_values(["car ID","timestamp"], inplace=True) # sort values by car ID and timestamp
STR_Nov.set_index(pd.DatetimeIndex(STR_Nov["timestamp"]),inplace=True) # make timestamp index and transform to datetime
STR_Nov.drop("timestamp", axis=1, inplace=True) # drop datetime column

# %%
# check out the data
STR_Nov.head(10)
# Out:
#                                 car ID     long       lat
# timestamp
# 2017-11-01 00:10:01  WDD2428901J014865  9.25371  48.76507  \
# 2017-11-01 00:15:01  WDD2428901J014865  9.25371  48.76507
# 2017-11-01 00:20:01  WDD2428901J014865  9.25371  48.76507
# 2017-11-01 00:25:01  WDD2428901J014865  9.25371  48.76507
# 2017-11-01 00:30:01  WDD2428901J014865  9.25371  48.76507
# 2017-11-01 00:35:01  WDD2428901J014865  9.25371  48.76507
# 2017-11-01 01:25:02  WDD2428901J014865  9.16111  48.77170
# 2017-11-01 01:30:01  WDD2428901J014865  9.16111  48.77170
# 2017-11-01 01:35:01  WDD2428901J014865  9.16111  48.77170
# 2017-11-01 01:40:01  WDD2428901J014865  9.16111  48.77170
#
#                                                   address  tank/charge level
# timestamp
# 2017-11-01 00:10:01    Heiligenwiesen 31, 70327 Stuttgart                 55  \
# 2017-11-01 00:15:01    Heiligenwiesen 31, 70327 Stuttgart                 55
# 2017-11-01 00:20:01    Heiligenwiesen 31, 70327 Stuttgart                 55
# 2017-11-01 00:25:01    Heiligenwiesen 31, 70327 Stuttgart                 55
# 2017-11-01 00:30:01    Heiligenwiesen 31, 70327 Stuttgart                 55
# 2017-11-01 00:35:01    Heiligenwiesen 31, 70327 Stuttgart                 55
# 2017-11-01 01:25:02  HasenbergstraÃe 32, 70176 Stuttgart                 43
# 2017-11-01 01:30:01  HasenbergstraÃe 32, 70176 Stuttgart                 43
# 2017-11-01 01:35:01  HasenbergstraÃe 32, 70176 Stuttgart                 43
# 2017-11-01 01:40:01  HasenbergstraÃe 32, 70176 Stuttgart                 43
#
#                      charging
# timestamp
# 2017-11-01 00:10:01         0
# 2017-11-01 00:15:01         0
# 2017-11-01 00:20:01         0
# 2017-11-01 00:25:01         0
# 2017-11-01 00:30:01         0
# 2017-11-01 00:35:01         0
# 2017-11-01 01:25:02         0
# 2017-11-01 01:30:01         0
# 2017-11-01 01:35:01         0
# 2017-11-01 01:40:01         0

# %%
# note the type of the index
type(STR_Nov.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# familiarize yourself with the data
print(STR_Nov.info())
print(STR_Nov.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1393195 entries, 2017-11-01 00:10:01 to 2017-11-14 21:45:01
# Data columns (total 6 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   car ID             1393195 non-null  object
#  1   long               1393195 non-null  float64
#  2   lat                1393195 non-null  float64
#  3   address            1393195 non-null  object
#  4   tank/charge level  1393195 non-null  int64
#  5   charging           1393195 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 74.4+ MB
# None
#                long           lat  tank/charge level      charging
# count  1.393195e+06  1.393195e+06       1.393195e+06  1.393195e+06
# mean   9.170557e+00  4.876111e+01       7.241289e+01  3.100356e-02
# std    7.507871e-02  3.899275e-02       2.098999e+01  1.733273e-01
# min    8.946480e+00  4.865150e+01       1.300000e+01  0.000000e+00
# 25%    9.128420e+00  4.873205e+01       5.700000e+01  0.000000e+00
# 50%    9.171520e+00  4.876570e+01       7.400000e+01  0.000000e+00
# 75%    9.212760e+00  4.878886e+01       9.100000e+01  0.000000e+00
# max    9.350120e+00  4.885262e+01       1.000000e+02  1.000000e+00

# %% [markdown]
# ### 1.2 Data prep and engineering: datetime
#
# The dataset contains temporal data. Therefore, we can generate interesting features from the datetime information.

# %%
# Let's map time of day and day of week to our DF
def get_date(ts):
    return ts.date()

def get_weekday(ts):
    return ts.weekday()

def get_hour(ts):
    return ts.hour

# %% [markdown]
# For this we will be using `lambda` in combination with `.apply()` - a very powerful combination for row-wise operations which allows you to apply any self-defined function to an element in a df.

# %%
STR_Nov.reset_index(inplace=True) # first, we reset the index so that timestamp becomes a column of our dataframe
STR_Nov["Date"] = STR_Nov["timestamp"].apply(lambda x: get_date(x))
STR_Nov["Weekday"]=STR_Nov["timestamp"].apply(lambda x: get_weekday(x))
STR_Nov["Hour"]=STR_Nov["timestamp"].apply(lambda x: get_hour(x))

STR_Nov.head()
# Out:
#             timestamp             car ID     long       lat
# 0 2017-11-01 00:10:01  WDD2428901J014865  9.25371  48.76507  \
# 1 2017-11-01 00:15:01  WDD2428901J014865  9.25371  48.76507
# 2 2017-11-01 00:20:01  WDD2428901J014865  9.25371  48.76507
# 3 2017-11-01 00:25:01  WDD2428901J014865  9.25371  48.76507
# 4 2017-11-01 00:30:01  WDD2428901J014865  9.25371  48.76507
#
#                               address  tank/charge level  charging
# 0  Heiligenwiesen 31, 70327 Stuttgart                 55         0  \
# 1  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 2  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 3  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 4  Heiligenwiesen 31, 70327 Stuttgart                 55         0
#
#          Date  Weekday  Hour
# 0  2017-11-01        2     0
# 1  2017-11-01        2     0
# 2  2017-11-01        2     0
# 3  2017-11-01        2     0
# 4  2017-11-01        2     0

# %% [markdown]
# Most of the time, there is a faster alternative. In this case, you can also use the .dt accessor for datetime columns:

# %%
STR_Nov['timestamp'].dt.date
# Out:
# 0          2017-11-01
# 1          2017-11-01
# 2          2017-11-01
# 3          2017-11-01
# 4          2017-11-01
#               ...
# 1393190    2017-11-14
# 1393191    2017-11-14
# 1393192    2017-11-14
# 1393193    2017-11-14
# 1393194    2017-11-14
# Name: timestamp, Length: 1393195, dtype: object

# %%
STR_Nov['Date']
# Out:
# 0          2017-11-01
# 1          2017-11-01
# 2          2017-11-01
# 3          2017-11-01
# 4          2017-11-01
#               ...
# 1393190    2017-11-14
# 1393191    2017-11-14
# 1393192    2017-11-14
# 1393193    2017-11-14
# 1393194    2017-11-14
# Name: Date, Length: 1393195, dtype: object

# %% [markdown]
# ### 1.3 Data prep and engineering: merge further data
#
# You might have interesting information from other sources that you want to include in your analysis. First, let's pretend that Car2Go provides us with a second dataset that contains information on the type of cars in their fleet.

# %%
# first, we generate our hypothetical car model data
brands = ["Fiat", "BMW", "Volkswagen", "Ford", "Volvo", "Tesla", "Porsche"]
seats = [2,3,4,5]
color = ["grey", "black", "blue", "red", "green"]

car_models = pd.DataFrame({"car_id": STR_Nov["car ID"].unique()})
car_models["brand"] = np.random.choice(brands, len(car_models))
car_models["seats"] = np.random.choice(seats, len(car_models))
car_models["color"] = np.random.choice(color, len(car_models))

car_models.head()
# Out:
#               car_id  brand  seats color
# 0  WDD2428901J014865  Tesla      2  grey
# 1  WDD2428901J014882    BMW      4  grey
# 2  WDD2428901J014884   Fiat      3   red
# 3  WDD2428901J014886   Ford      3  grey
# 4  WDD2428901J014888  Tesla      3   red

# %%
# next, we merge the car model data with our main dataframe
STR_Nov_cars = STR_Nov.merge(car_models, how = "left", left_on = "car ID", right_on = "car_id")

STR_Nov_cars.head()
# Out:
#             timestamp             car ID     long       lat
# 0 2017-11-01 00:10:01  WDD2428901J014865  9.25371  48.76507  \
# 1 2017-11-01 00:15:01  WDD2428901J014865  9.25371  48.76507
# 2 2017-11-01 00:20:01  WDD2428901J014865  9.25371  48.76507
# 3 2017-11-01 00:25:01  WDD2428901J014865  9.25371  48.76507
# 4 2017-11-01 00:30:01  WDD2428901J014865  9.25371  48.76507
#
#                               address  tank/charge level  charging
# 0  Heiligenwiesen 31, 70327 Stuttgart                 55         0  \
# 1  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 2  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 3  Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 4  Heiligenwiesen 31, 70327 Stuttgart                 55         0
#
#          Date  Weekday  Hour             car_id  brand  seats color
# 0  2017-11-01        2     0  WDD2428901J014865  Tesla      2  grey
# 1  2017-11-01        2     0  WDD2428901J014865  Tesla      2  grey
# 2  2017-11-01        2     0  WDD2428901J014865  Tesla      2  grey
# 3  2017-11-01        2     0  WDD2428901J014865  Tesla      2  grey
# 4  2017-11-01        2     0  WDD2428901J014865  Tesla      2  grey

# %% [markdown]
# Second, let's pretend that we have information on the urban traffic congestion in Stuttgart. Specifically, we have information on the average additional time spent during a 10km car trip in the inner city for every hour

# %%
# first, we generate our hypothetical congestion data
congestion = pd.DataFrame({'timestamp': pd.date_range('2017-11-01', '2017-11-15', periods=85, inclusive='left')})
congestion["congestion"] = np.random.randint(0,20, len(congestion))

# %%
congestion.head()
# Out:
#             timestamp  congestion
# 0 2017-11-01 00:00:00          12
# 1 2017-11-01 04:00:00           8
# 2 2017-11-01 08:00:00          16
# 3 2017-11-01 12:00:00           8
# 4 2017-11-01 16:00:00          15

# %%
# next, we merge the congestion data with our main dataframe
# note that in contrast to the car model data, we do not have any column that exactly matches in both dataframes
# for merges on datetime, pd.merge_asof comes to the rescue

# for this to work, both dataframes must be sorted by datetime
STR_Nov.sort_values("timestamp", inplace=True)

STR_Nov_congestion = pd.merge_asof(STR_Nov, congestion, on = "timestamp", direction = "nearest")

# %%
# let's return to our original sorting by car ID and timestamp and inspect the data
STR_Nov_congestion.sort_values(["car ID","timestamp"], inplace=True)

STR_Nov_congestion.head(10)
# Out:
#                timestamp             car ID     long       lat
# 729  2017-11-01 00:10:01  WDD2428901J014865  9.25371  48.76507  \
# 1295 2017-11-01 00:15:01  WDD2428901J014865  9.25371  48.76507
# 1464 2017-11-01 00:20:01  WDD2428901J014865  9.25371  48.76507
# 1989 2017-11-01 00:25:01  WDD2428901J014865  9.25371  48.76507
# 2206 2017-11-01 00:30:01  WDD2428901J014865  9.25371  48.76507
# 2356 2017-11-01 00:35:01  WDD2428901J014865  9.25371  48.76507
# 6081 2017-11-01 01:25:02  WDD2428901J014865  9.16111  48.77170
# 6319 2017-11-01 01:30:01  WDD2428901J014865  9.16111  48.77170
# 6746 2017-11-01 01:35:01  WDD2428901J014865  9.16111  48.77170
# 7060 2017-11-01 01:40:01  WDD2428901J014865  9.16111  48.77170
#
#                                    address  tank/charge level  charging
# 729     Heiligenwiesen 31, 70327 Stuttgart                 55         0  \
# 1295    Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 1464    Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 1989    Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 2206    Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 2356    Heiligenwiesen 31, 70327 Stuttgart                 55         0
# 6081  HasenbergstraÃe 32, 70176 Stuttgart                 43         0
# 6319  HasenbergstraÃe 32, 70176 Stuttgart                 43         0
# 6746  HasenbergstraÃe 32, 70176 Stuttgart                 43         0
# 7060  HasenbergstraÃe 32, 70176 Stuttgart                 43         0
#
#             Date  Weekday  Hour  congestion
# 729   2017-11-01        2     0          12
# 1295  2017-11-01        2     0          12
# 1464  2017-11-01        2     0          12
# 1989  2017-11-01        2     0          12
# 2206  2017-11-01        2     0          12
# 2356  2017-11-01        2     0          12
# 6081  2017-11-01        2     1          12
# 6319  2017-11-01        2     1          12
# 6746  2017-11-01        2     1          12
# 7060  2017-11-01        2     1          12

# %% [markdown]
# ### Task <br>
#
# - In the above merge operation, set the direction to "nearest", "backward" and "forward"
# - What changes? Which option makes most sense in the given context?

# %% [markdown]
# ### 1.4 Data prep and engineering: locations
#
# The dataset contains geospatial data. Therefore, we can generate interesting features from the location information. To do that, we first convert our dataframe to a gepandas dataframe that allows for geographical operations on so called geometry columns.

# %%
# let's load the Stuttgart locations data and convert it to a geopandas dataframe
# note: x and y replace lon and lat here (long, lat) = (x, y)
stuttgart_loc = pd.read_csv("Stuttgart_POIS.csv")
shopping_pois = gpd.GeoDataFrame(stuttgart_loc, geometry=gpd.points_from_xy(stuttgart_loc['lon'], stuttgart_loc['lat']))

# %%
shopping_pois.head()
# Out:
#    Unnamed: 0                                               tags  version
# 0           0  {"brand:wikidata":"Q16968817","brand:wikipedia...        0  \
# 1           1  {"addr:suburb":"Lustnau","contact:phone":"+49 ...        0
# 2           2  {"fax":"+49 7071 84629","source":"knowledge","...        0
# 3           3  {"amenity":"fuel","compressed_air":"yes","fuel...        0
# 4           4  {"amenity":"fuel","fuel:diesel":"yes","fuel:oc...        0
#
#          lat       lon  timestamp        id  changeset  addr:city
# 0  48.530796  9.079883          0  31605827        0.0   Tübingen  \
# 1  48.530790  9.079736          0  31605828        0.0   Tübingen
# 2  48.530870  9.079653          0  31605830        0.0   Tübingen
# 3  48.719585  9.207897          0  32589162        0.0  Stuttgart
# 4  48.514980  9.225251          0  33657618        0.0        NaN
#
#   addr:country  ...         shop tobacco trade  watches wholesale brand
# 0           DE  ...  supermarket     NaN   NaN      NaN       NaN  REWE  \
# 1           DE  ...       bakery     NaN   NaN      NaN       NaN   NaN
# 2           DE  ...      butcher     NaN   NaN      NaN       NaN   NaN
# 3           DE  ...        kiosk     NaN   NaN      NaN       NaN  Agip
# 4          NaN  ...        kiosk     NaN   NaN      NaN       NaN   NaN
#
#                    geometry osm_type agrarian kiosk
# 0  POINT (9.07988 48.53080)     node      NaN   NaN
# 1  POINT (9.07974 48.53079)     node      NaN   NaN
# 2  POINT (9.07965 48.53087)     node      NaN   NaN
# 3  POINT (9.20790 48.71959)     node      NaN   NaN
# 4  POINT (9.22525 48.51498)     node      NaN   NaN
#
# [5 rows x 53 columns]

# %%
# next, we convert our Car2Go dataframe to a geopandas dataframe
# note: x and y replace long and lat here (long, lat) = (x, y)
str_nov_geo = gpd.GeoDataFrame(STR_Nov, geometry=gpd.points_from_xy(STR_Nov['long'], STR_Nov['lat']))

# %%
str_nov_geo.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour                  geometry
# 1355588         0  2017-11-01        2     0  POINT (9.16004 48.78306)
# 767009          1  2017-11-01        2     0  POINT (9.15871 48.81197)
# 504851          0  2017-11-01        2     0  POINT (9.01996 48.70894)
# 540369          1  2017-11-01        2     0  POINT (9.29360 48.75934)
# 1084629         0  2017-11-01        2     0  POINT (9.15659 48.84287)

# %% [markdown]
# Notice the difference between the dataframes before and after: there is a new column called geometry. This is a column that enables the geopandas operations on this dataframe.

# %%
str_nov_geo.plot()
# Out:
# <Axes: >

# %% [markdown]
# Here you can see a nice feature - plotting the geometries on a map. It is hard to see anything, so later we are going to add a layer with a map.

# %% [markdown]
# Up for the next step. In the shopping POIs we fetched from Open Street Map, you can see a collection of shops with a LOT of attributes. Don't be scared, there are some that are useful to us. A later column is called 'shop' and it contains different shop types

# %%
shopping_pois.head()
# Out:
#    Unnamed: 0                                               tags  version
# 0           0  {"brand:wikidata":"Q16968817","brand:wikipedia...        0  \
# 1           1  {"addr:suburb":"Lustnau","contact:phone":"+49 ...        0
# 2           2  {"fax":"+49 7071 84629","source":"knowledge","...        0
# 3           3  {"amenity":"fuel","compressed_air":"yes","fuel...        0
# 4           4  {"amenity":"fuel","fuel:diesel":"yes","fuel:oc...        0
#
#          lat       lon  timestamp        id  changeset  addr:city
# 0  48.530796  9.079883          0  31605827        0.0   Tübingen  \
# 1  48.530790  9.079736          0  31605828        0.0   Tübingen
# 2  48.530870  9.079653          0  31605830        0.0   Tübingen
# 3  48.719585  9.207897          0  32589162        0.0  Stuttgart
# 4  48.514980  9.225251          0  33657618        0.0        NaN
#
#   addr:country  ...         shop tobacco trade  watches wholesale brand
# 0           DE  ...  supermarket     NaN   NaN      NaN       NaN  REWE  \
# 1           DE  ...       bakery     NaN   NaN      NaN       NaN   NaN
# 2           DE  ...      butcher     NaN   NaN      NaN       NaN   NaN
# 3           DE  ...        kiosk     NaN   NaN      NaN       NaN  Agip
# 4          NaN  ...        kiosk     NaN   NaN      NaN       NaN   NaN
#
#                    geometry osm_type agrarian kiosk
# 0  POINT (9.07988 48.53080)     node      NaN   NaN
# 1  POINT (9.07974 48.53079)     node      NaN   NaN
# 2  POINT (9.07965 48.53087)     node      NaN   NaN
# 3  POINT (9.20790 48.71959)     node      NaN   NaN
# 4  POINT (9.22525 48.51498)     node      NaN   NaN
#
# [5 rows x 53 columns]

# %%
# let's filter our location data 
shopping_pois = shopping_pois[shopping_pois['brand'] == 'Lidl'] # we now only want Lidl for later analysis
shopping_pois.dropna(axis='columns', thresh=25, inplace=True) # lets also drop NA columns, as they are not useful for us. The thresh parameter can be used to control how many entries have to be there to keep the column
shopping_pois = shopping_pois[shopping_pois['addr:city'] == 'Stuttgart'] # finally, we are only interested in locations in the city of Stuttgart

shopping_pois.head()
# Out:
#      Unnamed: 0                                               tags  version
# 21           21  {"brand:wikidata":"Q151954","brand:wikipedia":...        0  \
# 141         141  {"brand:wikidata":"Q151954","brand:wikipedia":...        0
# 146         146  {"addr:suburb":"Botnang","contact:email":"kont...        0
# 167         167  {"brand:wikidata":"Q151954","brand:wikipedia":...        0
# 427         427  {"addr:suburb":"Mitte","brand:wikidata":"Q1519...        0
#
#            lat       lon  timestamp         id  changeset  addr:city
# 21   48.811302  9.165339          0   59656294        0.0  Stuttgart  \
# 141  48.779740  9.167623          0  264885086        0.0  Stuttgart
# 146  48.778800  9.125645          0  266175760        0.0  Stuttgart
# 167  48.775486  9.155695          0  268510495        0.0  Stuttgart
# 427  48.773495  9.173240          0  311737339        0.0  Stuttgart
#
#     addr:country addr:housenumber  addr:postcode         addr:street  name
# 21            DE               32        70469.0  Stuttgarter Straße  Lidl  \
# 141           DE               12        70174.0   Breitscheidstraße  Lidl
# 146           DE                2        70195.0         Griegstraße  Lidl
# 167           DE               91        70193.0        Schwabstraße  Lidl
# 427           DE               12        70178.0        Marienstraße  Lidl
#
#                                  opening_hours                      operator
# 21   Mo-Fr 08:00-21:00; Sa 08:00-21:00; PH off  Lidl Vertriebs-GmbH & Co. KG  \
# 141  Mo-Fr 08:00-21:00; Sa 08:00-21:00; PH off  Lidl Vertriebs-GmbH & Co. KG
# 146  Mo-Fr 07:00-21:00; Sa 07:00-21:00; PH off  Lidl Vertriebs-GmbH & Co. KG
# 167                  Mo-Sa 07:00-22:00; PH off  Lidl Vertriebs-GmbH & Co. KG
# 427  Mo-Fr 08:00-22:00; Sa 08:00-22:00; PH off  Lidl Vertriebs-GmbH & Co. KG
#
#             shop brand                  geometry osm_type
# 21   supermarket  Lidl  POINT (9.16534 48.81130)     node
# 141  supermarket  Lidl  POINT (9.16762 48.77974)     node
# 146  supermarket  Lidl  POINT (9.12565 48.77880)     node
# 167  supermarket  Lidl  POINT (9.15569 48.77549)     node
# 427  supermarket  Lidl  POINT (9.17324 48.77349)     node

# %% [markdown]
# Now we have two geodataframes, both with geographical information. However, the coordinates might be in differing formats. Coordinate reference systems (short CRS) are used to tell you: we have defined the coordinates to follow this particular model. We are using one called WGS84, that can be found using a code from a database. That database is called EPSG. In it, WGS84 has the code 4326.

# %%
# there is currently no coordinate reference system set for either of the two dataframes
print(str_nov_geo.crs)
print(shopping_pois.crs)
# Out:
# None
# None

# %%
# to make the two geodataframes speak to each other, we need to set the crs for both to be equal
str_nov_geo = str_nov_geo.set_crs(epsg=4326)
shopping_pois = shopping_pois.set_crs(epsg=4326)

# %%
# now, the crs in both dataframes is defined
str_nov_geo.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
shopping_pois.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# check out the first LIDL supermarket in our list
shopping_pois.iloc[0]
# Out:
# Unnamed: 0                                                         21
# tags                {"brand:wikidata":"Q151954","brand:wikipedia":...
# version                                                             0
# lat                                                         48.811302
# lon                                                          9.165339
# timestamp                                                           0
# id                                                           59656294
# changeset                                                         0.0
# addr:city                                                   Stuttgart
# addr:country                                                       DE
# addr:housenumber                                                   32
# addr:postcode                                                 70469.0
# addr:street                                        Stuttgarter Straße
# name                                                             Lidl
# opening_hours               Mo-Fr 08:00-21:00; Sa 08:00-21:00; PH off
# operator                                 Lidl Vertriebs-GmbH & Co. KG
# shop                                                      supermarket
# brand                                                            Lidl
# geometry                                   POINT (9.165339 48.811302)
# osm_type                                                         node
# Name: 21, dtype: object

# %%
# we could calculate the distance for each Car2Go location to this supermarket easily using the .distance function
str_nov_geo.distance(shopping_pois.iloc[0].geometry)
# Out:
# /var/folders/w2/qvkw67fs4gz183wq08fkfbx80000gp/T/ipykernel_4291/2304221872.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   str_nov_geo.distance(shopping_pois.iloc[0].geometry)
# 1355588    0.028735
# 767009     0.006663
# 504851     0.177801
# 540369     0.138387
# 1084629    0.032758
#              ...
# 1257593    0.049720
# 69338      0.082942
# 1018211    0.052910
# 760835     0.067751
# 310241     0.036889
# Length: 1393195, dtype: float64

# %% [markdown]
# Distance calculation is actually quite simple for a single point, as you can see above. However the CRS strikes again... The warning above tells you that the distance results are likely to be complete rubbish. That is because the distance is calculated between degrees and not points in meters. To get good results, we need to convert the coordinates to a projected CRS, which is given in meters.

# %% [markdown]
# A nice website for looking up CRS is epsg.io. There we can search for a variety of CRS. On such projected system that gives coordinates in meters is Europe UTM. UTM is a projection that is split into 'slices'. Each slice is valid only for a part of the earth, which depends on the location you want to model. Use epsg.io to find the respective EPSG-code, which in our case is 25837. That we can simply enter into the conversion as you see below.

# %%
str_nov_geo = str_nov_geo.to_crs(epsg=25837)
str_nov_geo.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour                          geometry
# 1355588         0  2017-11-01        2     0  POINT (-1674638.247 5848117.906)
# 767009          1  2017-11-01        2     0  POINT (-1673384.661 5851282.209)
# 504851          0  2017-11-01        2     0  POINT (-1688111.645 5844439.999)
# 540369          1  2017-11-01        2     0  POINT (-1666200.956 5841448.190)
# 1084629         0  2017-11-01        2     0  POINT (-1672093.973 5854685.356)

# %% [markdown]
# Now the geometries look strange, don't they? Actually, they are now more useful. The values you see there are the meters this point is away from (0,0). Now you can't really tell where on earth these locations are without knowing where (0,0) is, but you can calculate the distance using the euclidean formula! Lets put this to use.

# %%
shopping_pois = shopping_pois.to_crs(epsg=25837) # remember to change the CRS for our supermarket data as well
str_nov_geo['distance to Lidl Stuttgarter Str.'] = str_nov_geo.distance(shopping_pois.iloc[0].geometry) # calculate the distance to the first LIDL using .distance

# %%
str_nov_geo.sort_values(by=['distance to Lidl Stuttgarter Str.', 'timestamp'])
# Out:
#                   timestamp             car ID     long       lat
# 36432   2017-11-11 10:45:01  WDD2428901J014914  9.16492  48.81139  \
# 36433   2017-11-11 10:50:01  WDD2428901J014914  9.16492  48.81139
# 36434   2017-11-11 10:55:01  WDD2428901J014914  9.16492  48.81139
# 36435   2017-11-11 11:00:01  WDD2428901J014914  9.16492  48.81139
# 36436   2017-11-11 11:05:01  WDD2428901J014914  9.16492  48.81139
# ...                     ...                ...      ...       ...
# 139452  2017-11-14 23:50:01  WME4513901K649351  8.94648  48.65150
# 1132664 2017-11-14 23:50:01  WME4513901K728529  8.94648  48.65150
# 1280532 2017-11-14 23:55:01  WME4513901K820086  8.94648  48.65150
# 139453  2017-11-14 23:55:01  WME4513901K649351  8.94648  48.65150
# 1132665 2017-11-14 23:55:01  WME4513901K728529  8.94648  48.65150
#
#                                                 address  tank/charge level
# 36432              Stuttgarter Str. 36, 70469 Stuttgart                 70  \
# 36433              Stuttgarter Str. 36, 70469 Stuttgart                 70
# 36434              Stuttgarter Str. 36, 70469 Stuttgart                 70
# 36435              Stuttgarter Str. 36, 70469 Stuttgart                 70
# 36436              Stuttgarter Str. 36, 70469 Stuttgart                 70
# ...                                                 ...                ...
# 139452   IBM | Ein- und Ausfahrt nur Ã¼ber Haupteingang                 87
# 1132664  IBM | Ein- und Ausfahrt nur Ã¼ber Haupteingang                100
# 1280532  IBM | Ein- und Ausfahrt nur Ã¼ber Haupteingang                100
# 139453   IBM | Ein- und Ausfahrt nur Ã¼ber Haupteingang                 88
# 1132665  IBM | Ein- und Ausfahrt nur Ã¼ber Haupteingang                100
#
#          charging        Date  Weekday  Hour
# 36432           0  2017-11-11        5    10  \
# 36433           0  2017-11-11        5    10
# 36434           0  2017-11-11        5    10
# 36435           0  2017-11-11        5    11
# 36436           0  2017-11-11        5    11
# ...           ...         ...      ...   ...
# 139452          1  2017-11-14        1    23
# 1132664         0  2017-11-14        1    23
# 1280532         0  2017-11-14        1    23
# 139453          1  2017-11-14        1    23
# 1132665         0  2017-11-14        1    23
#
#                                  geometry  distance to Lidl Stuttgarter Str.
# 36432    POINT (-1672968.638 5851028.227)                          34.169991
# 36433    POINT (-1672968.638 5851028.227)                          34.169991
# 36434    POINT (-1672968.638 5851028.227)                          34.169991
# 36435    POINT (-1672968.638 5851028.227)                          34.169991
# 36436    POINT (-1672968.638 5851028.227)                          34.169991
# ...                                   ...                                ...
# 139452   POINT (-1696062.694 5840515.928)                       25388.285189
# 1132664  POINT (-1696062.694 5840515.928)                       25388.285189
# 1280532  POINT (-1696062.694 5840515.928)                       25388.285189
# 139453   POINT (-1696062.694 5840515.928)                       25388.285189
# 1132665  POINT (-1696062.694 5840515.928)                       25388.285189
#
# [1393195 rows x 12 columns]

# %% [markdown]
# Now we can see the distance to this Lidl for all cars, isn't that nice? For important locations in a city, like the central station, this can be very informative.
#
# Given that we have lots of Lidls in Stuttgart, wouldn't it be a lot nicer to use more than just a single supermarket? Consider this idea: We create a circle around all supermarkets in Stuttgart, generate a geometry from this and finally simply check whether the location of a car is currently in one of these circles or not!

# %%
buffered_shops = shopping_pois.buffer(50) # create a circle of 50 meters around all points
all_shops = buffered_shops.unary_union # change format from series to single object

# %%
# check whether the Car2Go locations is within any of the circles around our Lidls
str_nov_geo['close_to_some_LIDL'] = str_nov_geo.within(all_shops)

# %%
# note the newly created binary variable
str_nov_geo.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour
# 1355588         0  2017-11-01        2     0  \
# 767009          1  2017-11-01        2     0
# 504851          0  2017-11-01        2     0
# 540369          1  2017-11-01        2     0
# 1084629         0  2017-11-01        2     0
#
#                                  geometry  distance to Lidl Stuttgarter Str.
# 1355588  POINT (-1674638.247 5848117.906)                        3348.789336  \
# 767009   POINT (-1673384.661 5851282.209)                         521.147501
# 504851   POINT (-1688111.645 5844439.999)                       16528.834219
# 540369   POINT (-1666200.956 5841448.190)                       11696.206851
# 1084629  POINT (-1672093.973 5854685.356)                        3776.191618
#
#          close_to_some_LIDL
# 1355588               False
# 767009                False
# 504851                False
# 540369                False
# 1084629               False

# %% [markdown]
# ### Task: What do you observe? <br>
#
# - Play around with the above dataframe trying using commands such as `df.head()`, `df.describe()` or `df.info()`
# - What data is gathered, for what period, in what format and at which frequency?
# - How do you explain the sudden jumps in the time-stamp?
# - What can you infer about the status of each car?

# %%
### YOUR CODE HERE

# %% [markdown]
# ## `Descriptive Analyses`

# %% [markdown]
# Next, let's dive deeper and use graphs and plots to help us understand the data.

# %% [markdown]
# ### 2.1 Fleet Size and availability

# %%
# first, let's explore fleet size
fleet_size = len(STR_Nov["car ID"].unique())

print("The STR fleet consists of {} cars (for the observed time frame)".format(fleet_size))
# Out:
# The STR fleet consists of 489 cars (for the observed time frame)

# %% [markdown]
# Note that in STR the full active car fleet is electric and therefore constitutes a potential distributed energy resource (DER) that can be used to provide flexibility. The fleet consists of Smart EQ fortwos and Mercedes Benz A Class models each with a battery of size 17.6 kWh and charging rates of 6 kW (22kW optional).

# %% [markdown]
# Let's explore fleet availability throughout the week and day by checking how many unique cars are available for each day and hour of day.

# %%
# Availability over time (5 min intervals)
STR_Nov_Date_avail = STR_Nov.groupby("timestamp")["car ID"].nunique() # this counts unique vehicles per 5-min time interval

fig,ax = plt.subplots(figsize=(16,9)) 

ax.plot(STR_Nov_Date_avail)
ax.set_title("Cars available per time interval",fontsize=16)

plt.show()

# %% [markdown]
# Next we perform some aggregations. We are interested in typical availability
# - by day of week
# - by hour

# %%
# Availability by day of week (0 = Monday, 6 = Sunday)

STR_Nov_weekday_avail = STR_Nov.groupby(["Date","Weekday"])["car ID"].nunique()
STR_Nov_weekday_avail = pd.DataFrame(STR_Nov_weekday_avail)
STR_Nov_weekday_avail
# Out:
#                     car ID
# Date       Weekday
# 2017-11-01 2           460
# 2017-11-02 3           468
# 2017-11-03 4           457
# 2017-11-04 5           459
# 2017-11-05 6           463
# 2017-11-06 0           461
# 2017-11-07 1           469
# 2017-11-08 2           471
# 2017-11-09 3           471
# 2017-11-10 4           477
# 2017-11-11 5           476
# 2017-11-12 6           476
# 2017-11-13 0           477
# 2017-11-14 1           476

# %%
fig,ax = plt.subplots(figsize=(10,4)) 

sns.boxplot(x=STR_Nov_weekday_avail.index.get_level_values(1), y=STR_Nov_weekday_avail["car ID"],ax=ax)
plt.show()

# %%
# Availability by time of day

STR_Nov_time_avail = STR_Nov.groupby(["Date","Hour"])["car ID"].nunique()
STR_Nov_time_avail = pd.DataFrame(STR_Nov_time_avail)

# %%
fig,ax = plt.subplots(figsize=(10,4)) 

sns.boxplot(x=STR_Nov_time_avail.index.get_level_values(1), y=STR_Nov_time_avail["car ID"],ax=ax)
plt.show()

# %% [markdown]
# ### Task: What do you observe? <br>
#
# - Describe the patterns of car availability shown in the descriptive graphs above. Which graphs are particularly instructive?
# - What are your assumptions regarding the cause of the observed patterns?
# - How would you expect the plot to look like if we were to plot the number of trips started?

# %% [markdown]
# ### 2.2 Car Movement & Location Intelligence
#
# How can we infer car movement from this data? Let's have a look at what the data provides. A lot of what follows below is a demonstation of possible geospatial analytics tasks with limited implications for VPP operations. It is, however, highly relevant from a fleet operator's point of view (Where is the demand? Where should my units be at what time?)
#
# **Technical note**: for this tutorial we use `folium` for visualization (see [here](https://www.kaggle.com/daveianhickey/how-to-folium-for-maps-heatmaps-time-data) for a quick introduction). For more comprehensive functionality, `geopandas` offers a powerful Python GIS data handling and plotting library (see [here](http://geopandas.org)).

# %%
# we first zip the latitude and longitude data
STR_Nov["Coordinates"] = list(zip(STR_Nov["lat"].round(4),STR_Nov["long"].round(4)))

STR_Nov.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour        Coordinates
# 1355588         0  2017-11-01        2     0    (48.7831, 9.16)
# 767009          1  2017-11-01        2     0   (48.812, 9.1587)
# 504851          0  2017-11-01        2     0    (48.7089, 9.02)
# 540369          1  2017-11-01        2     0  (48.7593, 9.2936)
# 1084629         0  2017-11-01        2     0  (48.8429, 9.1566)

# %% [markdown]
# Let us check where cars are typically located by plotting a heat map of locations for a given hour of the day.

# %%
# For performance reasons we select a single car only - pick randomly from the list
car_list = STR_Nov["car ID"].unique()
selected_car_ID = random.choice(car_list)
print(selected_car_ID)
# Out:
# WME4513901K667619

# %%
# define new map
STR_heat_map = folium.Map(location=(48.76507, 9.25371),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

# add heat map
STR_heat_map.add_child(plugins.HeatMap(STR_Nov[STR_Nov["car ID"]==selected_car_ID]["Coordinates"], radius=20))

STR_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b42747834438ae0cab1021414beef88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b42747834438ae0cab1021414beef88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b42747834438ae0cab1021414beef88 = L.map(
#                 &quot;map_4b42747834438ae0cab1021414beef88&quot;,
#                 {
#                     center: [48.76507, 9.25371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4b42747834438ae0cab1021414beef88);
#
#
#
#
#
#             var tile_layer_c8e126b1802e68bfc95347ca4fc09175 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b42747834438ae0cab1021414beef88);
#
#
#             var heat_map_a301a806ae085fecfd939cc4df339900 = L.heatLayer(
#                 [[48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.19

# %% [markdown]
# We now wish to identify the movement of the selected car. To do this, we draw the location points and trajectories.

# %%
# define empty map
STR_map_points = folium.Map(location=(48.76507, 9.25371),  tiles='Stamen Toner', 
                       zoom_start=10, control_scale=True, max_zoom=20)


# draw positions for selcted car
STR_Nov_car_select = STR_Nov[STR_Nov["car ID"]==selected_car_ID]

positions = list(STR_Nov_car_select["Coordinates"].unique())
for position in positions:
    folium.CircleMarker(radius=10, location=position, popup='The Waterfront', 
                                 color='crimson', fill_color='crimson').add_to(STR_map_points)
    
STR_map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24f9160a0d6b1bd6687bf230cd5f0060 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24f9160a0d6b1bd6687bf230cd5f0060&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24f9160a0d6b1bd6687bf230cd5f0060 = L.map(
#                 &quot;map_24f9160a0d6b1bd6687bf230cd5f0060&quot;,
#                 {
#                     center: [48.76507, 9.25371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_24f9160a0d6b1bd6687bf230cd5f0060);
#
#
#
#
#
#             var tile_layer_d28b403a5315a8bc31c6dee752258cdf = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24f9160a0d6b1bd6687bf230cd5f0060);
#
#
#             var circle_marker_3e0b930ff05248e893554ba90aea3d64 = L.circleMarker(
#                 [48.7495, 9.2154],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_24f9160a0d6b1bd6687bf230cd5f0060);
#
#
#         var popup_8bc5212d99bdb578ba36a9aa7206328b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5be6106e2b75be4255adc426bd7d66b9 = $(`&lt;div id=&quot;html_5be6106e2b75be4255adc426bd7d66b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_8bc5212d99bdb578ba36a9aa7206328b.setContent(html_5be6106e2b75be4255adc426bd7d66b9);
#
#
#
#         circle_marker_3e0b930ff05248e893554ba90aea3d64.bindPopup(popup_8bc5212d99bdb578ba36a9aa7206328b)
#         ;
#
#
#
#
#             var circle_marker_c5f798949b3d00c36c05bd2d1a56098d = L.circleMarker(
#                 [48.7057, 9.2209],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_24f9160a0d6b1bd6687bf230cd5f0060);
#
#
#         var popup_031be04f2d7eaa3406b1e95cdfa69bd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c110679ade1f280929275fc09470ef71 = $(`&lt;div id=&quot;html_c110679ade1f280929275fc09470ef71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_031be04f2d7eaa3406b1e95cdfa69bd7.setContent(html_c110679ade1f280929275fc09470ef71);
#
#
#
#         circle_marker_c5f798949b3d00c36c05bd2d1a56098d.bindPopup(popup_031be04f2d7eaa3406b1e95cdfa69bd7)
#         ;
#
#
#
#
#             var circle_marker_447d8fe9b17ee601a539399037486642 = L.circleMarker(
#                 [48.7356, 9.2143],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_24f9160a0d6b1bd6687bf230cd5f0060);
#
#
#         var popup_812853fb34ee8de8106a5dc4d730a44a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_001a60e7b695432bc728902e2b1514a9 = $(`&lt;div id=&quot;html_001a60e7b695432bc728902e2b1514a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_812853fb34ee8de8106a5dc4d730a44a.setContent(html_001a60e7b695432bc728902e2b1514a9);
#
#
#
#         circle_marker_447d8fe9b17ee601a539399037486642.bindPopup(popup_812853fb34ee8d

# %% [markdown]
# We also add the trajectories to get an understanding of the distance traveled. Do you see any problem with such an approach?

# %%
STR_map_trajectory = folium.Map(location=(48.76507, 9.25371),  tiles='Stamen Toner', 
                       zoom_start=11, control_scale=True, max_zoom=20)

# draw trajectory for a selected car
folium.PolyLine(STR_Nov_car_select["Coordinates"],color="blue", weight=5, opacity=0.8, ).add_to(STR_map_trajectory)
STR_map_trajectory
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_685d957c7d5954c921fdd9592a217dfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_685d957c7d5954c921fdd9592a217dfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_685d957c7d5954c921fdd9592a217dfc = L.map(
#                 &quot;map_685d957c7d5954c921fdd9592a217dfc&quot;,
#                 {
#                     center: [48.76507, 9.25371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_685d957c7d5954c921fdd9592a217dfc);
#
#
#
#
#
#             var tile_layer_6dd2e889f8b571bcbcb2e34b5a908b66 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_685d957c7d5954c921fdd9592a217dfc);
#
#
#             var poly_line_0611e13382eeb9f31e5c9911cb51cd51 = L.polyline(
#                 [[48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48

# %% [markdown]
# ### Task
#
# - Combine the three maps into one by defining a new map and adding all three layers to that map. How does it look?

# %%
# define empty map
STR_map_combined = folium.Map(location=(48.76507, 9.25371),  tiles='Stamen Toner', 
                       zoom_start=9, control_scale=True, max_zoom=20)


# add heatmap
STR_map_combined.add_child(plugins.HeatMap(STR_Nov[STR_Nov["car ID"]==selected_car_ID]["Coordinates"],
                                           radius=20))

# add positions
STR_Nov_car_select = STR_Nov[STR_Nov["car ID"]==selected_car_ID]

positions = list(STR_Nov_car_select["Coordinates"].unique())
for position in positions:
    folium.CircleMarker(radius=5, location=position, popup='The Waterfront', 
                                 color='crimson', fill_color='crimson').add_to(STR_map_combined)

# add trajectories
folium.PolyLine(STR_Nov_car_select["Coordinates"],color="blue", weight=5, opacity=0.8, ).add_to(STR_map_combined)

# plot map
STR_map_combined
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57ff805db27246d06965eb61172d99e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57ff805db27246d06965eb61172d99e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57ff805db27246d06965eb61172d99e0 = L.map(
#                 &quot;map_57ff805db27246d06965eb61172d99e0&quot;,
#                 {
#                     center: [48.76507, 9.25371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_57ff805db27246d06965eb61172d99e0);
#
#
#
#
#
#             var tile_layer_65d627173850440e323411b9ad18c3bd = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57ff805db27246d06965eb61172d99e0);
#
#
#             var heat_map_bb35c663f39c3ef590513b4d4a469684 = L.heatLayer(
#                 [[48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7495, 9.2154], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7057, 9.2209], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7356, 9.2143], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198], [48.7149, 9.198],

# %% [markdown]
# **Note**: from the data we can also infer where charging points must be located. Let's have a look...

# %% [markdown]
# ### Task
#
# - How would you identify charging positions?

# %%
STR_Nov.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour        Coordinates
# 1355588         0  2017-11-01        2     0    (48.7831, 9.16)
# 767009          1  2017-11-01        2     0   (48.812, 9.1587)
# 504851          0  2017-11-01        2     0    (48.7089, 9.02)
# 540369          1  2017-11-01        2     0  (48.7593, 9.2936)
# 1084629         0  2017-11-01        2     0  (48.8429, 9.1566)

# %%
# How many charging locations are there?
len(list(STR_Nov[STR_Nov["charging"]==1]["Coordinates"].unique()))
# Out:
# 355

# %%
# YOUR CODE BELOW

# define dataset for plotting, i.e. charging_pos
charging_pos=list(STR_Nov[STR_Nov["charging"]==1]["Coordinates"].unique())

# define empty map
STR_map_charging = folium.Map(location=(48.76507, 9.25371),  tiles='Stamen Toner', 
                       zoom_start=9, control_scale=True, max_zoom=20)


# draw positions of charging positions
for charge_point in charging_pos:
    folium.CircleMarker(radius=3, location=charge_point, popup='The Waterfront', 
                                 color='green', fill_color='green').add_to(STR_map_charging)
    
STR_map_charging
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df08a514dba68e5ea10734399d44eb81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df08a514dba68e5ea10734399d44eb81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df08a514dba68e5ea10734399d44eb81 = L.map(
#                 &quot;map_df08a514dba68e5ea10734399d44eb81&quot;,
#                 {
#                     center: [48.76507, 9.25371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_df08a514dba68e5ea10734399d44eb81);
#
#
#
#
#
#             var tile_layer_0aa98cf70cfde4d55d3d52941a1e4088 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df08a514dba68e5ea10734399d44eb81);
#
#
#             var circle_marker_313ea6916fb76791f7d0a0b91c7130b8 = L.circleMarker(
#                 [48.812, 9.1587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df08a514dba68e5ea10734399d44eb81);
#
#
#         var popup_1d5ef41f209bcae8d7a7005dcda27293 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59f96e2a8ccd6068c85ee077d4210695 = $(`&lt;div id=&quot;html_59f96e2a8ccd6068c85ee077d4210695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_1d5ef41f209bcae8d7a7005dcda27293.setContent(html_59f96e2a8ccd6068c85ee077d4210695);
#
#
#
#         circle_marker_313ea6916fb76791f7d0a0b91c7130b8.bindPopup(popup_1d5ef41f209bcae8d7a7005dcda27293)
#         ;
#
#
#
#
#             var circle_marker_5957ac60055a7b8bc4a6f38c6b26dc0a = L.circleMarker(
#                 [48.7593, 9.2936],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df08a514dba68e5ea10734399d44eb81);
#
#
#         var popup_8f3bfb76b5f07f738c4f8f964f213ad4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_594a3e34446ec0e685f1c99204050989 = $(`&lt;div id=&quot;html_594a3e34446ec0e685f1c99204050989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_8f3bfb76b5f07f738c4f8f964f213ad4.setContent(html_594a3e34446ec0e685f1c99204050989);
#
#
#
#         circle_marker_5957ac60055a7b8bc4a6f38c6b26dc0a.bindPopup(popup_8f3bfb76b5f07f738c4f8f964f213ad4)
#         ;
#
#
#
#
#             var circle_marker_5fc8f0af63117977881a801a894f3c8d = L.circleMarker(
#                 [48.7788, 9.148],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_df08a514dba68e5ea10734399d44eb81);
#
#
#         var popup_b85293c48df4b353b6cbd34674ca8507 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47e65f4c6d8b88c2dc6a8bf43b853eb7 = $(`&lt;div id=&quot;html_47e65f4c6d8b88c2dc6a8bf43b853eb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_b85293c48df4b353b6cbd34674ca8507.setContent(html_47e65f4c6d8b88c2dc6a8bf43b853eb7);
#
#
#
#         circle_marker_5fc8f0af63117977881a801a894f3c8d.bindPopup(popup_b85293c48df4b353b6cbd34674ca8507

# %% [markdown]
# ### Task & Discussion: Limitations and how to deal with them?
#
# - Play around with the map above and try for different vehicles by repeatedly executing the code - What do you observe?
# - What are the key limitations of this data granularity?
# - What are approaches to infering distance traveled?
# - What are approaches to infering the exact route traveled?

# %% [markdown]
# ### 2.3 Capacity Availability
#
# We now wish to understand how much capacity we have available at any given point in time and can, therefore, use to trade in the ancillary market. For this we first need to define how many cars are charging at a particular instance. Also, remember the following technical information regarding the fleet:
#
# - Battery capacity: 17.6 kWh
# - Charging rate: 6 kW
# - Optional fast charging: 22 kW

# %% [markdown]
# #### 2.3.1 Capacity for trading in the ancillary services market

# %%
Battery_energy_capa = 17.6 #kWh
Charging_rate = 6 #kW
Charging_rate_fast = 22 #kW
Max_EV_range = 200 #km

# %%
# Cars connected at a given point in time (we can simply sum the charging dummies)
STR_Nov_charging = STR_Nov.groupby("timestamp")["charging"].sum()

fig,ax = plt.subplots(figsize=(16,9)) 

ax.plot(STR_Nov_charging)

ax.set_title("# cars connected at a given point in time")
ax.set_ylabel("# of cars")
ax.set_xlabel("Date")

plt.show()

# %%
# Let us look at trends over the day - How many cars get connected per hour per time of day?
STR_Nov_charging_tod = pd.DataFrame(STR_Nov[STR_Nov["charging"]==1]).groupby(["Date","Hour"])["car ID"].nunique()
STR_Nov_charging_tod = pd.DataFrame(STR_Nov_charging_tod)

STR_Nov_charging_tod.head(10)
# Out:
#                  car ID
# Date       Hour
# 2017-11-01 0         27
#            1         18
#            2         16
#            3         13
#            4         19
#            5         30
#            6         35
#            7         37
#            8         26
#            9         11

# %%
fig,ax = plt.subplots(figsize=(16,9)) 

sns.boxplot(x=STR_Nov_charging_tod.index.get_level_values(1), y=STR_Nov_charging_tod["car ID"],ax=ax)
ax.set_title("# cars connected by time of day (hour intervals)")
plt.show()

# %%
# after knowing the number of cars (= number of batteries) connected, let's transform this into available capacity
fig, ax = plt.subplots(figsize=(16,9), ncols=2, nrows=1, sharex=True, sharey=True)

STR_Nov_capa_normal = STR_Nov.groupby("timestamp")["charging"].sum()*Charging_rate
STR_Nov_capa_fast = STR_Nov.groupby("timestamp")["charging"].sum()*Charging_rate_fast

# Normal speed______
ax[0].set_title("Capacity per 5 min slot with 6kW charging [kW]")
ax[0].plot(STR_Nov_capa_normal, "--b")

# fast speed_______
ax[1].set_title("Capacity per 5 min slot with 22kW charging [kW]")
ax[1].plot(STR_Nov_capa_fast, "--g")

plt.show()

# %% [markdown]
# ### Task:
#
# - What patterns do you see? Why? Do you see scope for building a strong predictive model?
# - How do you evaluate the case of using the VPP in the ancillary services markets (secondary reserve) (compare fast charging and normal charging case)? Given current market designs, can an EV VPP be successful?
# - Is there scope for raising capacity at a given point in time? What are innovative apporaches towards raising available capacity at any given point in time? (compare against # of idle cars, charging station positions etc.)
# - Recall the mechanism of the secondary reserve market: participants use bids for a capacity price for every 15min. Do you see any issues/constraints in using electric vehicle batteries as secondary reserve? How can the fleet operator ensure that the VPP can deliver the required capacity over the full pledged period?

# %% [markdown]
# #### 2.3.2 What is the battery constraint for balancing capacity provision?
#
# In the ancillary services market you pledge capacity (in kW) for which you get reimbursed. If you get called (either for upwards or downwards regulation) you need to feed in or consume at this rate (or below). Therefore, as a plant operator, you need to demonstrate that you will be able to sustain the pledged load for the full 15min time interval.
#
# To verify, we explore the state of charge across time for the cars that are charging as this will give us an indication for the energy that is available for upwards and downwards regulation (i.e. the time frame for which the VPP can be called) - an important constraint!

# %%
# connected battery capacity (in kWh)

# What do we have available for downwards regulation (i.e. how much energy can be absorbed?)
STR_Nov["Connected free Battery Capacity [kWh]"] = ((100-STR_Nov["tank/charge level"])/100)*Battery_energy_capa*STR_Nov["charging"]

# What do we have available for upwards regulation (i.e. how much energy can be fed back into the grid?)
STR_Nov["Connected SOC [kWh]"] = ((STR_Nov["tank/charge level"])/100)*Battery_energy_capa*STR_Nov["charging"]

STR_Nov.head()
# Out:
#                   timestamp             car ID     long       lat
# 1355588 2017-11-01 00:00:01  WME4513901K820402  9.16004  48.78306  \
# 767009  2017-11-01 00:00:01  WME4513901K682887  9.15871  48.81197
# 504851  2017-11-01 00:00:01  WME4513901K664097  9.01996  48.70894
# 540369  2017-11-01 00:00:01  WME4513901K666870  9.29360  48.75934
# 1084629 2017-11-01 00:00:01  WME4513901K728465  9.15659  48.84287
#
#                                             address  tank/charge level
# 1355588         KornbergstraÃe 32, 70176 Stuttgart                 81  \
# 767009     Wilhelm-Geiger-Platz 10, 70469 Stuttgart                 95
# 504851   Hugo-Distler-StraÃe 6, 71065 Sindelfingen                 84
# 540369     Sulzgrieser StraÃe 105, 73733 Esslingen                100
# 1084629           Marco-Polo-Weg 8, 70439 Stuttgart                100
#
#          charging        Date  Weekday  Hour        Coordinates
# 1355588         0  2017-11-01        2     0    (48.7831, 9.16)  \
# 767009          1  2017-11-01        2     0   (48.812, 9.1587)
# 504851          0  2017-11-01        2     0    (48.7089, 9.02)
# 540369          1  2017-11-01        2     0  (48.7593, 9.2936)
# 1084629         0  2017-11-01        2     0  (48.8429, 9.1566)
#
#          Connected free Battery Capacity [kWh]  Connected SOC [kWh]
# 1355588                                   0.00                 0.00
# 767009                                    0.88                16.72
# 504851                                    0.00                 0.00
# 540369                                    0.00                17.60
# 1084629                                   0.00                 0.00

# %%
Connected_downwards_energy = STR_Nov[STR_Nov["charging"]==1].groupby("timestamp")["Connected free Battery Capacity [kWh]"].sum()
Connected_upwards_energy = STR_Nov[STR_Nov["charging"]==1].groupby("timestamp")["Connected SOC [kWh]"].sum()

# %%
fig, ax = plt.subplots(figsize=(16,9), ncols=2, nrows=1, sharex=True, sharey=True)

# downwards capacity
ax[0].set_title("Downwards energy [kWh]")
ax[0].plot(Connected_downwards_energy, "--b")

# upwards capacity
ax[1].set_title("Upwards energy [kWh]")
ax[1].plot(Connected_upwards_energy, "--g")

plt.show()

# %% [markdown]
# ### Task:
#
# - How do you determine whether enough energy/storage capacity is available?
# - From inspecting the graph above and comparing with the available capacity from above, is there a relevant state of charge constraint? Is it a problem? How big of a problem is it?
# - How does this constraint influence the capacity that can be pledged in the capacity markets?
